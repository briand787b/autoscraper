# %%
import database
import json

# %%
pw = input('database password [default carvana]: ') or 'carvana'
port = int(input('database port [default 5432]: ') or '5432')
host = input('database host [default localhost]: ') or 'localhost'
eng = database.engine(pw, host=host, port=port, echo=True)
eng
# Out:
# database password [default carvana]:
# database port [default 5432]:  35432
# database host [default localhost]:
# Engine(postgresql://carvana:***@localhost:35432/carvana)

# %%
database.create_tables(eng)
# Out:
# 2023-02-15 19:55:52,142 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-02-15 19:55:52,143 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-02-15 19:55:52,144 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-02-15 19:55:52,145 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-02-15 19:55:52,146 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-02-15 19:55:52,147 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-02-15 19:55:52,149 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-02-15 19:55:52,151 INFO sqlalchemy.engine.Engine
#                 CREATE TABLE IF NOT EXISTS listings (
#                     id                          SERIAL PRIMARY KEY,
#                     body                        VARCHAR(24),
#                     carvana_id                  INTEGER,
#                     city                        VARCHAR(55),
#                     color                       VARCHAR(55),
# ...

# %%
with open('data/jupyter_listings.json', 'r') as file:
    listings = json.load(file)

# %%
database.save_listings(eng, listings)
# Out:
# 2023-02-15 07:34:46,012 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-02-15 07:34:46,015 INFO sqlalchemy.engine.Engine
#                 INSERT INTO listings
#                 (
#                     body,
#                     carvana_id,
#                     city,
#                     color,
#                     drive_type,
#                     engine,
#                     kbb_value,
#                     make,
#                     mfg_basic_warranty_miles,
#                     mfg_basic_warranty_months,
#                     mfg_dt_warranty_miles,
#                     mfg_dt_warranty_months,
#                     mileage,
#                     model,
#                     num_keys,
#                     price,
#                     rem_warranty_miles,
#                     rem_warranty_months,
#                     rem_dt_warranty_miles,
#                     rem_dt_warranty_months,
#                     seating,
#                     state,
# ...
