# %%
import json

# %%
with open('data/_feature.json', 'r') as file:
    pagejson = json.load(file)
    
vehicle = pagejson['props']['pageProps']['initialState']['vehicle']['details']

with open('data/_parse_vehicle.json', 'w+') as file:
    json.dump(vehicle, file)

# %%
listing = {
    'body_type': vehicle['bodyType'],
    'carvana_id': vehicle['vehicleId'],
    'city': vehicle['location']['city'],
    'drive_type': vehicle['drivetrainDescription'],
    'engine': vehicle['engineDescription'],
    'exterior_color': vehicle['exteriorColor'],
    'features': [ f['displayName'] for kf  in vehicle['kbbFeatures'] for f in kf['features']],
    'fuel': vehicle['fuelDescription'],
    'imperfections': [
        {
            'description': i['description'],
            'location': i['location'],
            'title': i['title'],
            'zone': i['zoneDescription'],
        } for i in vehicle['vexVdpImageData'].get('imperfections', [])
    ],
    'interior_color': vehicle['interiorColor'],
    'kbb_value': vehicle['kbbValue'],
    'make': vehicle['make'],
    'mfg_basic_warranty_miles': vehicle["manufacturerBasicWarrantyMiles"],
    'mg_basic_warranty_months': vehicle["manufacturerBasicWarrantyMonths"],
    'mfg_drivetrain_warranty_miles': vehicle["manufacturerDriveTrainWarrantyMiles"],
    'mfg_drivetrain_warranty_months': vehicle["manufacturerDriveTrainWarrantyMonths"],
    'mileage': vehicle['mileage'],
    'model': vehicle['model'],
    'num_keys': vehicle['numberOfKeys'],
    'options': vehicle['installedOptions'],
    'price': vehicle['price'],
    'remaining_warranty_miles': vehicle["remainingWarrantyMiles"],
    'remaining_warranty_months': vehicle["remainingWarrantyMonths"],
    'remaining_drivetrain_warranty_months': vehicle["remainingDriveTrainWarrantyMiles"],
    'remaining_drivetrain_warranty_miles': vehicle["remainingDriveTrainWarrantyMonths"],
    'state': vehicle['location']['stateAbbreviation'],
    'std_equipment': vehicle['standardEquipment'],
    'transmission': vehicle['transmission'],
    'trim': vehicle['trim'],
    'vin': vehicle['vin'],
    'year': vehicle['year'],
    'zip': vehicle['location']['zip5'],
}

with open('data/_listing.json', 'w+') as file:
    json.dump(listing, file)

# %%
import scrape as sc
import json
with open('data/dbug_vehicle.json', 'r') as file:
    pagejson = json.load(file)
    
output = sc.build_listing(pagejson)
output
# Out:
# {'body_type': 'Truck',
#  'carvana_id': 2596482,
#  'city': 'Chesterfield',
#  'drive_type': '4WD',
#  'engine': '6-Cyl, 4.0L',
#  'exterior_color': 'Black',
#  'features': ['Alloy Wheels',
#   'Hill Descent Control',
#   'Hill Start Assist Control',
#   'ABS (4-Wheel)',
#   'Vehicle Dynamic Control',
#   'Traction Control',
#   'Power Door Locks',
#   'Sliding Rear Window',
#   'Cruise Control',
#   'Keyless Entry',
#   'Air Conditioning',
#   'Power Windows',
#   'Dual Air Bags',
#   'Backup Camera',
#   'Side Air Bags',
#   'Head Curtain Air Bags',
#   'AM/FM Stereo',
#   'SiriusXM Satellite',
#   'CD/MP3 (Single Disc)',
#   'Bluetooth Wireless',
#   'Power Steering',
#   'Tilt Wheel',
#   'Rear Spoiler'],
#  'fuel': None,
#  'imperfections': [],
#  'interior_color': 'Beige',
#  'kbb_value': 25466,
#  'make': 'Nissan',
#  'mfg_basic_warranty_miles': 36000,
#  'mg_basic_warranty_months': 36,
#  'mfg_drivetrain_warranty_miles': 60000,
#  'mfg_drivetrain_warranty_months': 60,
#  'mileage': 37154,
#  'model': 'Frontier Crew Cab',
#  'num_keys': 1,
#  'options': [],
#  'price': 28590,
#  'remaining_warranty_miles': 0,
#  'remaining_warranty_months': 0,
#  'remaining_drivetrain_warranty_months': 22600,
#  'remaining_drivetrain_warranty_miles': 7,
#  'state': 'VA',
#  'std_equipment': ['FLOOR MATS',
#   '50 STATE EMISSION',
#   'ACTIVATION DISCLA',
#   'BED RAIL CAPS'],
#  'transmission': 'Automatic, 5 speed',
#  'trim': 'SV Pickup 4D 5 ft',
#  'vin': '1N6AD0EV6JN712284',
#  'year': 2018,
#  'zip': '23834'}

# %%
listing = {
    'body_type': vehicle['bodyType'],
    'carvana_id': vehicle['vehicleId'],
    'city': vehicle['location']['city'],
    'drive_type': vehicle['drivetrainDescription'],
    'engine': vehicle['engineDescription'],
    'exterior_color': vehicle['exteriorColor'],
    'features': [ f['displayName'] for kf  in vehicle['kbbFeatures'] for f in kf['features']],
    'fuel': vehicle['fuelDescription'],
    'imperfections': [
        {
            'description': i['description'],
            'location': i['location'],
            'title': i['title'],
            'zone': i['zoneDescription'],
        } for i in vehicle['vexVdpImageData'].get('imperfections', [])
    ],
    'interior_color': vehicle['interiorColor'],
    'kbb_value': vehicle['kbbValue'],
    'make': vehicle['make'],
    'mfg_basic_warranty_miles': vehicle["manufacturerBasicWarrantyMiles"],
    'mg_basic_warranty_months': vehicle["manufacturerBasicWarrantyMonths"],
    'mfg_drivetrain_warranty_miles': vehicle["manufacturerDriveTrainWarrantyMiles"],
    'mfg_drivetrain_warranty_months': vehicle["manufacturerDriveTrainWarrantyMonths"],
    'mileage': vehicle['mileage'],
    'model': vehicle['model'],
    'num_keys': vehicle['numberOfKeys'],
    'options': vehicle['installedOptions'],
    'price': vehicle['price'],
    'remaining_warranty_miles': vehicle["remainingWarrantyMiles"],
    'remaining_warranty_months': vehicle["remainingWarrantyMonths"],
    'remaining_drivetrain_warranty_months': vehicle["remainingDriveTrainWarrantyMiles"],
    'remaining_drivetrain_warranty_miles': vehicle["remainingDriveTrainWarrantyMonths"],
    'state': vehicle['location']['stateAbbreviation'],
    'std_equipment': vehicle['standardEquipment'],
    'transmission': vehicle['transmission'],
    'trim': vehicle['trim'],
    'vin': vehicle['vin'],
    'year': vehicle['year'],
    'zip': vehicle['location']['zip5'],
}

with open('data/_listing_expedition.json', 'w+') as file:
    json.dump(listing, file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 16
#       1 listing = {
#       2     'body_type': vehicle['bodyType'],
#       3     'carvana_id': vehicle['vehicleId'],
#       4     'city': vehicle['location']['city'],
#       5     'drive_type': vehicle['drivetrainDescription'],
#       6     'engine': vehicle['engineDescription'],
#       7     'exterior_color': vehicle['exteriorColor'],
#       8     'features': [ f['displayName'] for kf  in vehicle['kbbFeatures'] for f in kf['features']],
#       9     'fuel': vehicle['fuelDescription'],
#      10     'imperfections': [
#      11         {
#      12             'description': i['description'],
#      13             'location': i['location'],
#      14             'title': i['title'],
#      15             'zone': i['zoneDescription'],
# ---> 16         } for i in vehicle['vexVdpImageData'].get('imperfections', [])
#      17     ],
#      18     'interior_color': vehicle['interiorColor'],
#      19     'kbb_value': vehicle['kbbValue'],
#      20     'make': vehicle['make'],
#      21     'mfg_basic_warranty_miles': vehicle["manufacturerBasicWarrantyMiles"],
#      22     'mg_basic_warranty_months': vehicle["manufacturerBasicWarrantyMonths"],
#      23     'mfg_drivetrain_warranty_miles': vehicle["manufacturerDriveTrainWarrantyMiles"],
#      24     'mfg_drivetrain_warranty_months': vehicle["manufacturerDriveTrainWarrantyMonths"],
#      25     'mileage': vehicle['mileage'],
#      26     'model': vehicle['model'],
#      27     'num_keys': vehicle['numberOfKeys'],
#      28     'options': vehicle['installedOptions'],
#      29     'price': vehicle['price'],
#      30     'remaining_warranty_miles': vehicle["remainingWarrantyMiles"],
#      31     'remaining_warranty_months': vehicle["remainingWarrantyMonths"],
#      32     'remaining_drivetrain_warranty_months': vehicle["remainingDriveTrainWarrantyMiles"],
#      33     'remaining_drivetrain_warranty_miles': vehicle["remainingDriveTrainWarrantyMonths"],
#      34     'state': vehicle['location']['stateAbbreviation'],
#      35     'std_equipment': vehicle['standardEquipment'],
#      36     'transmission': vehicle['transmission'],
#      37     'trim': vehicle['trim'],
#      38     'vin': vehicle['vin'],
#      39     'year': vehicle['year'],
#      40     'zip': vehicle['location']['zip5'],
#      41 }
#      43 with open('data/_listing_expedition.json', 'w+') as file:
#      44     json.dump(listing, file)
#
# KeyError: 'vexVdpImageData'
